# %% [markdown]
# Задание 2

# %%
a_centered = np.vstack(((np.subtract(a[:,0], mean_a[0])),(np.subtract(a[:,1], mean_a[1])))).T
a_centered
# Out:
# array([[-1. , -2.4],
#        [ 0. , -0.4],
#        [ 1. ,  2.6],
#        [ 1. ,  1.6],
#        [-1. , -1.4]])
